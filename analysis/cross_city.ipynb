# %% [markdown]
# # Cross-City LVT Analysis
#
# Loads standardized CSVs from all cities and compares LVT impacts.
# No modeling or API calls — just reads `analysis/data/*.csv`.
#
# Run after running each city's `model.ipynb` to update the CSVs.

# %%
import re
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from lvt.style import apply_lvt_style, CATEGORY_COLORS, INCREASE_COLOR, DECREASE_COLOR
apply_lvt_style()

DATA_DIR = Path('data')
CANONICAL_TAX_YEAR = 2026   # when one scenario exists at several vintages, plot this one

# analysis/data/ holds more than standard exports -- single-tax ledgers, rent surfaces,
# opportunity-site lists, ratio studies. Concatenating those produced summary rows with no
# parcels and an infinite revenue-neutral %, because they carry no current_tax to aggregate.
REQUIRED_COLS = {'city', 'property_category', 'current_tax', 'new_tax',
                 'tax_change', 'tax_change_pct', 'model_type'}


# A few exports predate the _ty<year> convention under a name the suffix rule cannot pair to
# its replacement. Map them onto the scenario that supersedes them.
LEGACY_ALIASES = {'philadelphia_lycd_refined_prototype': 'philadelphia_lycd_refined'}


def _scenario_and_year(stem):
    """'philadelphia_lycd_ty2027' -> ('philadelphia_lycd', 2027). Unsuffixed -> (stem, None)."""
    if stem in LEGACY_ALIASES:
        return LEGACY_ALIASES[stem], None
    m = re.match(r'^(.*)_ty(\d{4})$', stem)
    return (m.group(1), int(m.group(2))) if m else (stem, None)


candidates, skipped = {}, []
for csv_path in sorted(DATA_DIR.glob('*.csv')):
    if csv_path.name == '.gitkeep':
        continue
    try:
        head = pd.read_csv(csv_path, nrows=1)
    except Exception as e:
        skipped.append((csv_path.stem, 'unreadable ({})'.format(e)))
        continue
    if not REQUIRED_COLS <= set(head.columns):
        skipped.append((csv_path.stem, 'not a standard export'))
        continue
    scenario, year = _scenario_and_year(csv_path.stem)
    candidates.setdefault(scenario, {})[year] = csv_path

# One vintage per scenario. Without this the legacy unsuffixed Philadelphia exports plotted
# alongside their _ty2026 replacements as if they were different cities -- and since those
# legacy files predate the abated/homestead classifier fix, one scenario showed up twice with
# two different millages.
dfs, superseded = [], []
for scenario in sorted(candidates):
    by_year = candidates[scenario]
    years = sorted(y for y in by_year if y is not None)
    pick = CANONICAL_TAX_YEAR if CANONICAL_TAX_YEAR in by_year else (years[-1] if years else None)
    superseded += sorted(by_year[y].stem for y in by_year if y != pick)
    df = pd.read_csv(by_year[pick])
    dfs.append(df)
    print(f'  {by_year[pick].stem}: {len(df):,} rows')

if skipped:
    print()
    print(f'Skipped {len(skipped)} non-standard file(s):')
    for stem, why in skipped:
        print(f'  - {stem} ({why})')
if superseded:
    print()
    print(f'Superseded by the canonical vintage (TY{CANONICAL_TAX_YEAR}): {len(superseded)}')
    for stem in superseded:
        print(f'  - {stem}')

if not dfs:
    raise RuntimeError('No city CSVs found in analysis/data/. Run city notebooks first.')

all_cities = pd.concat(dfs, ignore_index=True)
print()
print(f'Total: {len(all_cities):,} parcels across {all_cities["city"].nunique()} cities')
print(all_cities['city'].value_counts().to_string())
# Out:
#   albuquerque: 237,926 rows
#   allentown: 34,393 rows
#   baltimore: 238,442 rows
#   bellingham: 41,032 rows
#   bryan: 30,496 rows
#   charlottesville: 15,165 rows
#   cleveland: 158,448 rows
#   college_station: 28,158 rows
#   fort_collins: 70,553 rows
#   greeley: 33,184 rows
#   highlands_ranch: 16,185 rows
#   howard_county: 103,890 rows
#   media: 1,978 rows
#   newport_news: 54,472 rows
#   oak_forest: 10,701 rows
#   philadelphia_ty2026: 583,249 rows
#   philadelphia_lvt_ubi_lycd_ty2026_parcels: 583,249 rows
#   philadelphia_lvt_ubi_ty2026_parcels: 583,249 rows
#   philadelphia_lycd_ty2026: 583,249 rows
#   philadelphia_lycd_post_abatement_ty2026: 583,249 rows
#   philadelphia_lycd_reassessment_ty2026: 583,249 rows
#   philadelphia_lycd_reassessment_ty2026_e_gbm: 583,249 rows
#   philadelphia_lycd_reassessment_ty2026_s2_k20: 583,249 rows
#   philadelphia_lycd_reassessment_ty2026_s5: 583,249 rows
#   philadelphia_lycd_refined_ty2026: 583,249 rows
#   philadelphia_post_abatement_ty2026: 583,249 rows
#   princeton: 7,634 rows
#   pueblo: 47,167 rows
#   reading: 26,299 rows
#   reading_avm_land: 26,299 rows
#   reading_lycd: 26,299 rows
#   richmond: 76,879 rows
#   roanoke: 44,441 rows
#   rochester: 57,628 rows
#   rockville: 16,119 rows
#   southbend: 44,324 rows
#   st_paul: 72,437 rows
#   syracuse: 41,697 rows
#   washington_dc: 122,311 rows
#
# Skipped 31 non-standard file(s):
#   - philadelphia_abated_lvt_buckets (not a standard export)
#   - philadelphia_abated_lvt_distribution (not a standard export)
#   - philadelphia_abatement_phase_in_by_year (not a standard export)
#   - philadelphia_abatement_phase_in_designs (not a standard export)
#   - philadelphia_abatement_phase_in_exposure (not a standard export)
#   - philadelphia_abatement_phase_in_others (not a standard export)
#   - philadelphia_abatement_phase_in_peak (not a standard export)
#   - philadelphia_abatement_phase_in_rates (not a standard export)
#   - philadelphia_abatement_phase_in_value_share_rate_bare_by_year (not a standard export)
#   - philadelphia_abatement_phase_in_value_share_rate_bare_designs (not a standard export)
#   - philadelphia_abatement_phase_in_value_share_rate_bare_exposure (not a standard export)
#   - philadelphia_abatement_phase_in_value_share_rate_bare_others (not a standard export)
#   - philadelphia_abatement_phase_in_value_share_rate_bare_rates (not a standard export)
#   - philadelphia_equity_by_surface_bg_corr (not a standard export)
#   - philadelphia_equity_by_surface_edges (not a standard export)
#   - philadelphia_equity_by_surface_knn (not a standard export)
#   - philadelphia_equity_by_surface_strata (not a standard export)
#   - philadelphia_equity_by_surface_summary (not a standard export)
#   - philadelphia_lvt_opportunity_sites (not a standard export)
#   - philadelphia_lvt_ubi_lycd_ty2026 (not a standard export)
#   - philadelphia_lvt_ubi_ty2026 (not a standard export)
#   - philadelphia_ocd_land_assessment (not a standard export)
#   - philadelphia_ocd_land_assessment_by_category (not a standard export)
#   - philadelphia_ocd_rule_validation (not a standard export)
#   - philadelphia_single_tax_ty2026_kappa_bounds (not a standard export)
#   - philadelphia_single_tax_ty2026_ledger (not a standard export)
#   - philadelphia_single_tax_ty2026_lines (not a standard export)
#   - philadelphia_vacant_land_ratio_study (not a standard export)
#   - philadelphia_vacant_land_ratio_study_ty2026 (not a standard export)
#   - philadelphia_wage_tax_swap (not a standard export)
#   - philadelphia_wage_tax_swap_parcels (not a standard export)
#
# Superseded by the canonical vintage (TY2026): 9
#   - philadelphia
#   - philadelphia_ty2027
#   - philadelphia_lycd
#   - philadelphia_lycd_ty2027
#   - philadelphia_lycd_post_abatement
#   - philadelphia_lycd_post_abatement_ty2027
#   - philadelphia_lycd_refined_prototype
#   - philadelphia_post_abatement
#   - philadelphia_post_abatement_ty2027
# Total: 8,100,296 parcels across 39 cities
# city
# philadelphia_lvt_ubi_lycd_ty2026                583249
# philadelphia_lvt_ubi_ty2026                     583249
# philadelphia_lycd_ty2026                        583249
# philadelphia_lycd_post_abatement_ty2026         583249
# philadelphia_lycd_reassessment_ty2026           583249
# philadelphia_lycd_reassessment_ty2026_e_gbm     583249
# philadelphia_lycd_reassessment_ty2026_s2_k20    583249
# philadelphia_lycd_refined_ty2026                583249
# philadelphia_post_abatement_ty2026              583249
# philadelphia_lycd_reassessment_ty2026_s5        583249
# philadelphia_ty2026                             583249
# baltimore                                       238442
# albuquerque                                     237926
# cleveland                                       158448
# washington_dc                                   122311
# howard_county                                   103890
# richmond                                         76879
# st_paul                                          72437
# fort_collins                                     70553
# rochester                                        57628
# newport_news                                     54472
# pueblo                                           47167
# roanoke                                          44441
# southbend                                        44324
# syracuse                                         41697
# bellingham                                       41032
# allentown                                        34393
# greeley                                          33184
# bryan                                            30496
# college_station                                  28158
# reading                                          26299
# reading_avm_land                                 26299
# reading_lycd                                     26299
# highlands_ranch                                  16185
# rockville                                        16119
# charlottesville                                  15165
# oak_forest                                       10701
# princeton                                         7634
# media                                             1978

# %% [markdown]
# ## 1. Revenue and Parcel Summary

# %%
# Revenue and parcel count summary by city
summary = all_cities.groupby('city').agg(
    parcel_count=('current_tax', 'count'),
    taxable_parcels=('current_tax', lambda x: (x > 0).sum()),
    current_revenue=('current_tax', 'sum'),
    new_revenue=('new_tax', 'sum'),
    model_type=('model_type', 'first'),
    land_millage=('land_millage', 'first'),
    improvement_millage=('improvement_millage', 'first'),
).reset_index()

summary['revenue_neutral_pct'] = (
    (summary['new_revenue'] - summary['current_revenue']).abs() /
    summary['current_revenue'] * 100
).round(3)

summary['current_revenue_M'] = (summary['current_revenue'] / 1e6).round(1)
summary['new_revenue_M'] = (summary['new_revenue'] / 1e6).round(1)

display_cols = [
    'city', 'parcel_count', 'taxable_parcels', 'current_revenue_M',
    'new_revenue_M', 'revenue_neutral_pct', 'model_type', 'land_millage', 'improvement_millage'
]
print(summary[display_cols].to_string(index=False))
# Out:
#                                         city  parcel_count  taxable_parcels  current_revenue_M  new_revenue_M  revenue_neutral_pct                                                                      model_type  land_millage  improvement_millage
#                                  albuquerque        237926           224076              235.4          235.4                0.000                                                                  split_rate:4.0     26.396628             6.599157
#                                    allentown         34393            33073               41.7           41.7                0.000                                                                        full_lvt     52.070691             0.000000
#                                    baltimore        238442           220093             1153.2         1153.2                0.000                                                                  split_rate:4.0    104.544674            26.136169
#                                   bellingham         41032            41032              264.8          264.8                0.000                                                                  split_rate:4.0     13.964254             3.491064
#                                        bryan         30496            29644              198.9          198.9                0.000                                                                  split_rate:4.0     45.406438            11.351609
#                              charlottesville         15165            15165              119.5          119.5                0.000                                                                  split_rate:4.0     20.812376             5.203094
#                                    cleveland        158448           131163               83.0           83.0                0.000                                                                  split_rate:4.0     29.399617             7.349904
#                              college_station         28158            27534              291.2          291.2                0.000                                                                  split_rate:4.0     43.107149            10.776787
#                                 fort_collins         70553            70553              440.8          442.9                0.484                                                                  split_rate:4.0    252.033848            63.008462
#                                      greeley         33184            29036                1.4            1.4                0.000                                                                  split_rate:4.0      2.505442             0.626360
#                              highlands_ranch         16185            16080               55.1           55.1                0.000                                                                  split_rate:4.0    134.998195            33.749549
#                                howard_county        103890           103890              923.5          923.5                0.000                                                                  split_rate:4.0     24.025847             6.006462
#                                        media          1978             1911                1.8            1.8                0.000                                                                  split_rate:4.0      3.814513             0.953628
#                                 newport_news         54472            52700              262.1          262.1                0.000                                                                  split_rate:4.0     28.259012             7.064753
#                                   oak_forest         10701            10315               11.9           11.9                0.046                                                                  split_rate:4.0      4.549333             1.137333
#             philadelphia_lvt_ubi_lycd_ty2026        583249           546317             2141.7         5542.4              158.790 lvt_ubi:capture_1,cap_rate_0.05,city_held_harmless,rent_basis_taxable,land_lycd           NaN                  NaN
#                  philadelphia_lvt_ubi_ty2026        583249           546317             2141.7         4291.6              100.389  lvt_ubi:capture_1,cap_rate_0.05,city_held_harmless,rent_basis_taxable,land_opa           NaN                  NaN
#      philadelphia_lycd_post_abatement_ty2026        583249           546317             2368.6         2368.6                0.000                                      split_rate_4to1_lycd_post_abatement_ty2026     24.499361             6.124840
#        philadelphia_lycd_reassessment_ty2026        583249           546317             2141.7         2141.7                0.000                                                   reassessment:lycd_land_ty2026     12.200649            12.200649
#  philadelphia_lycd_reassessment_ty2026_e_gbm        583249           546317             2141.7         2141.7                0.000                                                  reassessment:e_gbm_land_ty2026     12.574410            12.574410
# philadelphia_lycd_reassessment_ty2026_s2_k20        583249           546317             2141.7         2141.7                0.000                                                 reassessment:s2_k20_land_ty2026     12.019674            12.019674
#     philadelphia_lycd_reassessment_ty2026_s5        583249           546317             2141.7         2141.7                0.000                                                     reassessment:s5_land_ty2026     12.070240            12.070240
#             philadelphia_lycd_refined_ty2026        583249           546317             2141.7         2141.7                0.000                                             split_rate_4to1_lycd_refined_ty2026     21.625044             5.406261
#                     philadelphia_lycd_ty2026        583249           546317             2141.7         2141.7                0.000                                                     split_rate_4to1_lycd_ty2026     22.151854             5.537963
#           philadelphia_post_abatement_ty2026        583249           546317             2368.6         2368.6                0.000                                           split_rate_4to1_post_abatement_ty2026     31.771101             7.942775
#                          philadelphia_ty2026        583249           546317             2141.7         2141.7                0.000                                                          split_rate_4to1_ty2026     28.726822             7.181705
#                                    princeton          7634             7483               39.2           39.2                0.000                                                                 split_rate_2to1      7.474522             3.737261
#                                       pueblo         47167            44496                1.1            1.1                0.000                                                                  split_rate:4.0      2.742529             0.685632
#                                      reading         26299            25428               27.0           27.0                0.000                                                                  split_rate:4.0     40.435470            10.108868
#                             reading_avm_land         26299            25428               27.0           27.0                0.000                                                         split_rate:4.0_avm_land      4.043772             1.010943
#                                 reading_lycd         26299            25428               27.0           27.0                0.000                                                             split_rate:4.0_lycd      7.133549             1.783387
#                                     richmond         76879            72249              526.0          526.0                0.000                                                                  split_rate:4.0     26.290510             6.572628
#                                      roanoke         44441            42091              155.4          155.4                0.000                                                                  split_rate:4.0     30.861480             7.715370
#                                    rochester         57628            57628              117.2          117.2                0.000                                                                  split_rate:4.0     38.940757             9.735189
#                                    rockville         16119            15586               45.3           45.3                0.000                                                    split_rate:4.0,homestead_sim      5.322732             1.330683
#                                    southbend         44324            41766               27.0           27.0                0.000                                                                  split_rate:4.0      9.307266             2.326817
#                                      st_paul         72437            72399              647.7          647.7                0.000                                                                  split_rate:4.0   4125.720851          1031.430213
#                                     syracuse         41697            39719               31.6           31.6                0.000                                                                  split_rate:4.0     22.589917             5.647479
#                                washington_dc        122311           122311             2490.2         2490.2                0.000                                                                  split_rate:4.0     20.487518             5.121879

# %% [markdown]
# ## 2. Tax Change Distribution by City

# %%
# % parcels with tax increase, by city (excluding zero-tax parcels)
taxable = all_cities[all_cities['current_tax'] > 0].copy()

direction = taxable.groupby('city').agg(
    pct_increase=('tax_change', lambda x: (x > 0).mean() * 100),
    pct_decrease=('tax_change', lambda x: (x < 0).mean() * 100),
    median_change_pct=('tax_change_pct', 'median'),
).reset_index().sort_values('pct_increase')

fig, ax = plt.subplots(figsize=(10, max(4, len(direction) * 0.5)))
cities = direction['city']
y = range(len(cities))
ax.barh(y, direction['pct_increase'], color=INCREASE_COLOR, alpha=0.8, label='% increase')
ax.barh(y, -direction['pct_decrease'], color=DECREASE_COLOR, alpha=0.8, label='% decrease')
ax.axvline(0, color='black', linewidth=0.8)
ax.set_yticks(list(y))
ax.set_yticklabels(cities)
ax.set_xlabel('% of taxable parcels')
ax.set_title('Tax Change Direction by City (at modeled ratio)')
ax.legend()
plt.tight_layout()
plt.show()

print(direction.to_string(index=False))
# Out:
#                                         city  pct_increase  pct_decrease  median_change_pct
#                                 reading_lycd     12.277804     87.722196         -45.810643
#                                       pueblo     16.134035     83.865965         -11.637704
#        philadelphia_lycd_reassessment_ty2026     19.470747     80.529253         -12.625504
#                                   oak_forest     20.358701     79.621910          -9.844331
#                     philadelphia_lycd_ty2026     24.255881     75.744119         -26.897330
#                                      greeley     25.154980     74.845020          -6.151448
#             philadelphia_lycd_refined_ty2026     26.159354     73.840646         -23.756628
#                                        media     26.792255     73.207745          -9.405320
#      philadelphia_lycd_post_abatement_ty2026     27.683744     72.316256         -20.684490
#                                 fort_collins     28.153303     71.807010         -13.521485
#                                      st_paul     28.757303     71.242697         -12.878358
#                              college_station     30.140917     69.859083          -9.310521
# philadelphia_lycd_reassessment_ty2026_s2_k20     30.566320     69.433680         -11.005431
#                                    southbend     30.584686     69.415314         -11.009898
#                             reading_avm_land     33.278276     66.721724         -16.667039
#                          philadelphia_ty2026     33.370186     66.629814         -11.000294
#                                    allentown     34.139631     65.860369         -19.440714
#  philadelphia_lycd_reassessment_ty2026_e_gbm     34.714827     65.285173          -8.312536
#     philadelphia_lycd_reassessment_ty2026_s5     35.259932     64.740068          -9.070389
#                                     syracuse     35.496865     64.503135          -6.009364
#                                    cleveland     37.977173     62.022827          -4.451819
#                                        bryan     42.352584     57.647416          -5.108240
#           philadelphia_post_abatement_ty2026     45.705881     54.294119          -6.892340
#                              charlottesville     46.844708     53.155292          -1.325095
#                                      roanoke     48.297736     51.702264          -0.497008
#                                  albuquerque     52.252361     47.747639           0.774492
#                                     richmond     52.348129     47.651871           1.241265
#                                    baltimore     52.515982     47.484018           4.144605
#                                   bellingham     54.910801     45.089199           2.594888
#                                    rochester     56.266051     43.733949           1.397102
#                                      reading     57.078811     42.921189           3.045753
#                              highlands_ranch     59.054726     40.945274           1.271191
#                                howard_county     66.152661     33.847339           6.860498
#                                    princeton     67.112121     32.887879           4.829202
#                                    rockville     77.980239     22.019761          11.480255
#                                 newport_news     84.352941     15.647059          13.629829
#                                washington_dc     93.317036      6.682964          62.285770
#             philadelphia_lvt_ubi_lycd_ty2026     99.587419      0.412581         105.333305
#                  philadelphia_lvt_ubi_ty2026     99.988285      0.000000          87.478017

# %% [markdown]
# ## 3. Property Category Comparison

# %%
# Median tax change % by property category × city
# Focus on the most common standard categories
focus_cats = [
    'Single Family Residential',
    'Commercial',
    'Vacant Land',
    'Large Multi-Family (5+ units)',
    'Small Multi-Family (2-4 units)',
]

cat_city = (
    taxable[taxable['property_category'].isin(focus_cats)]
    .groupby(['city', 'property_category'])
    ['tax_change_pct']
    .median()
    .unstack('property_category')
    .round(1)
)

print('Median tax change % by category and city:')
print(cat_city.to_string())

# Heatmap
if len(cat_city) > 1:
    fig, ax = plt.subplots(figsize=(max(8, len(cat_city.columns) * 2), max(4, len(cat_city) * 0.6)))
    im = ax.imshow(cat_city.values, cmap='RdYlGn_r', aspect='auto', vmin=-30, vmax=30)
    ax.set_xticks(range(len(cat_city.columns)))
    ax.set_xticklabels(cat_city.columns, rotation=30, ha='right')
    ax.set_yticks(range(len(cat_city.index)))
    ax.set_yticklabels(cat_city.index)
    plt.colorbar(im, ax=ax, label='Median tax change %')
    ax.set_title('Median Tax Change % by Category and City')
    for i in range(len(cat_city.index)):
        for j in range(len(cat_city.columns)):
            val = cat_city.values[i, j]
            if not np.isnan(val):
                ax.text(j, i, f'{val:.0f}%', ha='center', va='center', fontsize=9)
    plt.tight_layout()
    plt.show()
# Out:
# Median tax change % by category and city:
# property_category                             Commercial  Large Multi-Family (5+ units)  Single Family Residential  Small Multi-Family (2-4 units)  Vacant Land
# city
# albuquerque                                          NaN                            3.5                        0.0                            -3.4        129.1
# allentown                                           15.1                          -19.2                       -8.2                             NaN        112.8
# baltimore                                            NaN                            2.1                        2.0                            -0.8        151.5
# bellingham                                           NaN                           -9.5                        NaN                            -2.7         79.6
# bryan                                               28.2                          -24.0                       -8.3                            -8.6          NaN
# charlottesville                                     26.6                           -9.8                       -3.6                             2.4        112.4
# cleveland                                           -2.3                          -24.7                       -5.8                            -7.8        131.5
# college_station                                     41.7                          -17.9                       -9.7                            -7.8          NaN
# fort_collins                                         NaN                            NaN                      -14.3                             NaN        117.4
# greeley                                              5.0                            NaN                        NaN                             NaN          NaN
# highlands_ranch                                     21.4                            NaN                        2.1                             NaN          NaN
# howard_county                                        NaN                          -21.0                        9.2                            17.3         92.2
# media                                               12.1                            2.0                       -9.4                            -2.3         90.7
# newport_news                                         NaN                            3.6                       15.0                             NaN        139.5
# oak_forest                                          45.7                          -15.6                      -10.3                           -32.0        148.5
# philadelphia_lvt_ubi_lycd_ty2026                   137.1                           84.9                      101.9                            70.3       1715.9
# philadelphia_lvt_ubi_ty2026                         71.4                          107.2                       84.9                            71.4        357.2
# philadelphia_lycd_post_abatement_ty2026             -6.4                          -21.9                      -21.0                           -30.0        630.0
# philadelphia_lycd_reassessment_ty2026               -2.1                          -15.1                      -12.8                           -14.3        263.4
# philadelphia_lycd_reassessment_ty2026_e_gbm         12.4                           -4.1                       -8.9                            -9.0        -12.5
# philadelphia_lycd_reassessment_ty2026_s2_k20         5.2                           -5.1                      -11.3                           -12.7        -14.3
# philadelphia_lycd_reassessment_ty2026_s5            10.7                           -4.9                       -9.3                           -11.3        -13.8
# philadelphia_lycd_refined_ty2026                   -40.4                          -23.8                      -24.7                           -34.8        553.0
# philadelphia_lycd_ty2026                           -15.4                          -29.4                      -28.6                           -36.7        560.1
# philadelphia_post_abatement_ty2026                  -9.2                            7.8                       -2.8                            -9.2        127.0
# philadelphia_ty2026                                -17.9                           -2.5                      -12.1                           -17.9        105.2
# princeton                                           -0.7                          -13.5                        4.4                             5.8         33.1
# pueblo                                              -4.4                            NaN                      -12.5                             NaN        174.3
# reading                                              6.7                           12.8                       -0.4                            -0.8        110.4
# reading_avm_land                                   359.8                          227.4                      -35.6                           -24.8       1521.3
# reading_lycd                                       -42.0                          -31.5                      -52.2                           -46.8       2107.6
# richmond                                             NaN                          -18.6                       -0.5                             5.5        119.1
# roanoke                                              NaN                           -7.1                       -3.0                            -4.2        153.0
# rochester                                            NaN                            NaN                        1.1                             NaN          NaN
# rockville                                            NaN                          -35.5                       13.9                            -6.9         82.3
# southbend                                            NaN                            NaN                        NaN                             NaN        182.0
# st_paul                                              5.7                            3.5                      -14.0                           -17.3        145.8
# syracuse                                             4.8                            NaN                        NaN                             NaN        143.8
# washington_dc                                        NaN                           24.8                       57.8                            48.8        141.0

# %% [markdown]
# ## 4. Income Quintile Equity Comparison

# %%
# Income quintile analysis: median tax change % in each quintile, by city
# Only cities with Census data
with_census = all_cities[all_cities['median_income'].notna() & (all_cities['current_tax'] > 0)].copy()

if len(with_census) == 0:
    print('No Census data available yet. Run city notebooks with Census API key to populate.')
else:
    # Assign income quintile within each city
    with_census['income_quintile'] = with_census.groupby('city')['median_income'].transform(
        (lambda x: (
        pd.qcut(x.rank(method='first'), 5, labels=[1, 2, 3, 4, 5])
        if x.nunique() >= 5
        else pd.Series(
            pd.qcut(x, x.nunique(), labels=list(range(1, x.nunique() + 1)),
                    duplicates='drop'),
            index=x.index
        ) if x.nunique() >= 2
        else pd.Series([1] * len(x), index=x.index)
    ))
    )

    quintile_city = (
        with_census.groupby(['city', 'income_quintile'])
        ['tax_change_pct']
        .median()
        .unstack('income_quintile')
        .round(1)
    )

    fig, ax = plt.subplots(figsize=(9, max(4, len(quintile_city) * 0.7)))
    colors = plt.cm.Blues(np.linspace(0.4, 0.9, 5))
    for q, color in zip([1, 2, 3, 4, 5], colors):
        if q in quintile_city.columns:
            ax.barh(
                [f'{c} (Q{q})' for c in quintile_city.index],
                quintile_city[q],
                label=f'Q{q}',
                color=color,
                alpha=0.8,
            )
    ax.axvline(0, color='black', linewidth=0.8)
    ax.set_xlabel('Median tax change %')
    ax.set_title('Median Tax Change % by Income Quintile and City')
    ax.legend(title='Income Quintile (1=lowest)')
    plt.tight_layout()
    plt.show()

    print(quintile_city.to_string())
# Out:
# C:\Users\druss\AppData\Local\Temp\ipykernel_137116\2573220563.py:23: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   with_census.groupby(['city', 'income_quintile'])
# income_quintile                                  1     2     3     4     5
# city
# albuquerque                                    5.2   1.8  -0.8  -1.5  -0.5
# allentown                                    -31.7 -25.7 -12.5 -19.1   6.1
# baltimore                                     42.7  29.5  19.5 -10.4 -16.2
# bellingham                                     4.5   3.6   0.5   1.2   2.7
# bryan                                          3.0  -2.5  -3.6  -3.1 -12.3
# charlottesville                               -5.8  -3.5   0.1  -0.5   0.3
# cleveland                                     -3.5  -3.5  -4.7  -4.6  -6.4
# college_station                               -6.8  -5.0 -11.9 -10.3  -6.1
# fort_collins                                 -15.4 -13.4 -14.7 -11.4  -9.6
# greeley                                       -7.7  -6.4  -7.4  -4.2  -3.1
# highlands_ranch                               -1.9   2.5   2.9   1.6  -0.2
# howard_county                                  7.0   5.4   6.5   9.6   5.4
# media                                         -2.3  -9.4  -9.4  -9.4  -9.4
# newport_news                                   8.2   9.9  13.6  15.0  17.4
# oak_forest                                   -16.3  -9.8 -10.0  -7.1  -8.5
# philadelphia_lycd_post_abatement_ty2026      -20.0 -18.9 -18.8 -19.9 -24.3
# philadelphia_lycd_reassessment_ty2026        -12.1 -12.5 -12.6 -12.7 -13.4
# philadelphia_lycd_reassessment_ty2026_e_gbm  -12.0 -10.9 -10.2  -3.1   2.0
# philadelphia_lycd_reassessment_ty2026_s2_k20 -14.8 -13.6 -11.1  -6.7  -2.6
# philadelphia_lycd_reassessment_ty2026_s5     -15.5 -12.5  -9.6  -3.9   3.7
# philadelphia_lycd_refined_ty2026             -26.5 -25.6 -23.6 -22.2 -22.5
# philadelphia_lycd_ty2026                     -26.4 -26.2 -25.9 -26.4 -29.7
# philadelphia_post_abatement_ty2026            -9.2  -9.2   0.0   0.5  -5.5
# philadelphia_ty2026                          -17.9 -17.9  -7.9  -7.2 -11.9
# princeton                                      4.1   7.5   3.4   0.9   7.3
# pueblo                                       -11.1 -12.3 -12.5 -12.1  -9.9
# reading                                        0.5  -2.7   6.7   7.8  -1.0
# reading_avm_land                              -0.5  -7.1 -22.2 -24.0 -22.4
# reading_lycd                                 -40.5 -40.7 -48.3 -49.0 -49.1
# richmond                                       1.4   0.6   0.2   2.5   0.2
# roanoke                                       -0.0   0.6  -0.7  -1.4  -0.5
# rochester                                      4.4   4.0   1.6   0.0  -3.3
# rockville                                     14.6  13.6  13.4   7.7   8.2
# southbend                                    -15.0 -17.4 -13.3  -6.4  -3.7
# st_paul                                      -16.7 -15.6 -16.2 -13.4   3.5
# syracuse                                      -6.9  -7.9  -5.5  -4.6  -5.2
# washington_dc                                 56.2  68.3  65.0  63.2  58.6

# %% [markdown]
# ## 5. Minority Quintile Equity Comparison

# %%
# Minority quintile analysis: same structure as income quintile
with_census_m = all_cities[all_cities['minority_pct'].notna() & (all_cities['current_tax'] > 0)].copy()

if len(with_census_m) == 0:
    print('No Census minority data available yet.')
else:
    with_census_m['minority_quintile'] = with_census_m.groupby('city')['minority_pct'].transform(
        (lambda x: (
        pd.qcut(x.rank(method='first'), 5, labels=[1, 2, 3, 4, 5])
        if x.nunique() >= 5
        else pd.Series(
            pd.qcut(x, x.nunique(), labels=list(range(1, x.nunique() + 1)),
                    duplicates='drop'),
            index=x.index
        ) if x.nunique() >= 2
        else pd.Series([1] * len(x), index=x.index)
    ))
    )

    min_quintile_city = (
        with_census_m.groupby(['city', 'minority_quintile'])
        ['tax_change_pct']
        .median()
        .unstack('minority_quintile')
        .round(1)
    )

    print('Median tax change % by minority quintile and city (Q1=least minority, Q5=most minority):')
    print(min_quintile_city.to_string())
# Out:
# C:\Users\druss\AppData\Local\Temp\ipykernel_137116\3797561154.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   with_census_m.groupby(['city', 'minority_quintile'])
# Median tax change % by minority quintile and city (Q1=least minority, Q5=most minority):
# minority_quintile                                1     2     3     4     5
# city
# albuquerque                                    0.7  -0.1  -1.8   0.7   5.4
# allentown                                      6.9  -2.9 -20.3 -31.3 -29.8
# baltimore                                    -15.4  -8.0   1.7  35.5  45.3
# bellingham                                     8.2   4.8   0.8  -3.3   3.7
# bryan                                          5.1  -9.4  -7.7  -5.7   2.4
# charlottesville                                0.7  -0.9  -0.7  -4.8  -1.9
# cleveland                                     -5.4  -4.8  -4.2  -3.0  -4.2
# college_station                               -4.6 -12.0 -10.0 -10.6  -8.3
# fort_collins                                 -14.4 -11.3 -14.1 -12.0 -14.7
# greeley                                       -4.0  -4.1  -6.1  -7.6  -7.7
# highlands_ranch                                1.7  -1.5   2.6   2.4   0.9
# howard_county                                  9.4   5.1   5.7   8.3   6.3
# media                                         -9.4  -9.4  -9.4  -9.4  -9.4
# newport_news                                  18.7  16.0  12.3  13.1   0.2
# oak_forest                                    -9.3  -9.6 -11.5  -6.7 -13.1
# philadelphia_lycd_post_abatement_ty2026      -22.6 -21.8 -21.4 -17.4 -16.5
# philadelphia_lycd_reassessment_ty2026        -13.0 -12.8 -12.5 -12.4 -12.3
# philadelphia_lycd_reassessment_ty2026_e_gbm   -0.3   0.9  -6.2 -13.4 -15.3
# philadelphia_lycd_reassessment_ty2026_s2_k20  -4.4  -3.7  -7.1 -15.8 -18.4
# philadelphia_lycd_reassessment_ty2026_s5       1.9  -0.5  -6.4 -16.3 -17.9
# philadelphia_lycd_refined_ty2026             -22.1 -23.0 -25.2 -24.5 -25.7
# philadelphia_lycd_ty2026                     -28.8 -28.0 -26.8 -24.0 -24.0
# philadelphia_post_abatement_ty2026            -3.3  -3.1  -9.2  -9.2  -9.2
# philadelphia_ty2026                          -10.3 -10.2 -11.6 -17.9 -17.9
# princeton                                      6.7   7.9   3.8   0.2   4.4
# pueblo                                       -10.5 -11.1 -12.1 -12.1 -12.5
# reading                                        0.7   4.9   2.6   2.3   4.9
# reading_avm_land                             -30.7 -16.8 -17.9  -7.9  -8.5
# reading_lycd                                 -50.8 -47.1 -46.5 -42.1 -42.0
# richmond                                       3.1   1.9  -1.0  -1.4   3.3
# roanoke                                       -0.2   1.0  -0.0  -1.7  -1.4
# rochester                                     -3.7  -0.7   2.7   4.2   3.3
# rockville                                      9.6  14.5  11.5  12.1  10.0
# southbend                                     -5.4  -7.9  -8.8 -15.7 -18.8
# st_paul                                        2.8  -2.7 -15.6 -19.2 -18.6
# syracuse                                      -3.9  -4.3  -6.3  -6.3 -11.6
# washington_dc                                 57.0  59.5  69.6  71.7  54.0
